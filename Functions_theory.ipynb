# %% [markdown]
# 1. What is the difference between a function and a method in Python?
#
#     Functions are independent, while methods are dependent on an object.
#
#     Functions are called directly by name, while methods are called on an object instance.
#
#     Methods can access amd modify the state of the object   they belong to, while fuctions typically operate o their input arguments.

# %% [markdown]
# 2. Explain the concept of function arguments and parameters in Python.
#
#     Parameters are variables defined within the parentheses of a function's def statement. They act as placeholders for the values that the function expects to receive when it is called.
#
#     Arguments are the actual values passed to a function when it is called. These values are assigned to the corresponding parameters within the function's definition.

# %% [markdown]
# 3. What are the different ways to define and call a function in Python?
#
#    In Python, functions are defined using the def keyword.
#
#    Syntax to call a function:
#    def function_name():

# %% [markdown]
# 4. What is the purpose of the `return` statement in a Python function?
#
#     Used to send a value back to the caller. If omitted, the function implicitly returns None.

# %% [markdown]
# 5. What are iterators in Python and how do they differ from iterables?
#
#    An iterator is an object that represents a stream of data and provides a way to access the elements of an iterable one by one.
#
#    An iterable is a container of items, while an iterator is a stateful object that tracks the current position during iteration.

# %% [markdown]
# 6. Explain the concept of generators in Python and how they are defined. ;
#
#     Generators in Python are a special type of iterable that allows for the creation of iterators in a memory-efficient manner. They generate values on demand, one at a time, instead of storing all values in memory simultaneously. This makes them particularly useful for handling large datasets or infinite sequences.
#
#     Generators are defined using functions, but instead of using the return keyword to return a single value, they use the yield keyword to produce a sequence of values. generator functions.

# %% [markdown]
# 7. What are the advantages of using generators over regular functions?
#
#    Provides memory efficiency, handling infinite or large datasets, and enabling lazy evaluation.

# %% [markdown]
# 8. What is a lambda function in Python and when is it typically used?
#
#    A lambda function in Python, also known as an anonymous function, is a small, single-expression function defined without a name using the lambda keyword. Unlike regular functions defined with def, lambda functions are concise and typically used for short, simple operations.

# %% [markdown]
#  9. Explain the purpose and usage of the `map()` function in Python.
#
#     The map() function in Python serves the purpose of applying a specified function to each item in an iterable and returning an iterator that yields the results. This function streamlines data transformation by eliminating the need for explicit loops in many scenarios.

# %% [markdown]
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#
#     map() transforms each element individually.
#
#     filter() selects elements based on a condition.
#
#     reduce() aggregates elements into a single result.

# %% [markdown]
# 11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given list:[47,11,42,13];
#
# ![image.png](attachment:image.png)
